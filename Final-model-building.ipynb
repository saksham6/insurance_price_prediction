# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("processed_data.csv")

# %%
# Copy all the predictor variables into X dataframe
x = df.drop('insurance_cost', axis=1)

# Copy target into the y dataframe. 
y = df[['insurance_cost']]

# %%
# Split X and y into training and test set in 70:30 ratio
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3 , random_state=1)

# %%
# !pip install xgboost
import xgboost
regressor=xgboost.XGBRegressor()

# %%
regressor.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### R square of training data

# %%
regressor.score(x_train,y_train)
# Out:
# 0.9752296768668206

# %% [markdown]
# ### R square of testing data

# %%
regressor.score(x_test,y_test)
# Out:
# 0.9508306899459849

# %% [markdown]
# ### Defining function for Adjusted R Square

# %%
# Let's create a function to create adjusted R-Squared
def adj_r2(x,y):
    r2 = regressor.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %% [markdown]
# ### Adjusted R Square on training data

# %%
adj_r2(x_train,y_train)
# Out:
# 0.9752013339145542

# %% [markdown]
# ### Adjusted R Square on testing data

# %%
adj_r2(x_test,y_test)
# Out:
# 0.9506992036241396

# %% [markdown]
# ### Hyper Parameter Tuning with cross-validation technique

# %%
## Hyper Parameter Optimization


n_estimators = [500,1000]
max_depth = [90,100]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.01,0.1]
base_score=[0.25,0.5,0.75,1]
min_child_weight=[1,5,10,50]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'booster':booster,
    'base_score':base_score,
    'min_child_weight':min_child_weight
    }

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = regressor, param_grid = hyperparameter_grid, cv = 3)

# %%
grid_search.fit(x_train,y_train)
# Out:
# [13:33:34] WARNING: ..\src\learner.cc:576:
# Parameters: { "param_grid" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [13:33:52] WARNING: ..\src\learner.cc:576:
# Parameters: { "param_grid" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [13:34:06] WARNING: ..\src\learner.cc:576:
# Parameters: { "param_grid" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
# ...

# %% [markdown]
# ### R square of training data after hyper parameter tuning

# %%
grid_search.score(X_train1,y_train1)
# Out:
# 0.9727997376717882

# %%
grid_search.score(X_train,y_train)
# Out:
# 0.9727997376717882

# %% [markdown]
# ### R square of testing data after hyper parameter tuning

# %%
grid_search.score(X_test,y_test)
# Out:
# 0.9524925144024157

# %% [markdown]
# ### Adjusted R Square on training data after hyper parameter tuning

# %%
adj_r2(x_train,y_train)
# Out:
# 0.9752013339145542

# %% [markdown]
# ### Adjusted R Square on training data after hyper parameter tuning

# %%
adj_r2(x_test,y_test)
# Out:
# 0.9506992036241396

# %%
import pickle

# %%
# save the model to disk
pickle_out = open("testModel.pkl","wb")
pickle.dump(regressor, pickle_out)
loaded_model = pickle.load(open("testModel.pkl", "rb")) 
result = loaded_model.score(X_test1, y_test1) 
print(result)
# Out:
# 0.9508306899459849
